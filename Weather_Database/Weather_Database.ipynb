# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the Latitude and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    #generally, it isn't a good idea to add the pass statement to the except block. Ideally, we want to handle or catch each
    #error as it happens and do something specific like add another try block or print out the error.

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grindavik
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | kavaratti
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | bowen
# Processing Record 6 of Set 1 | maceio
# Processing Record 7 of Set 1 | hami
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | abong mbang
# Processing Record 12 of Set 1 | kangaatsiaq
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | khani
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | dinguiraye
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | berlevag
# Processing Record 22 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 1 | kasra
# City not found. Skipping...
# Processing Record 24 of Set 1 | ilo
# Processing Record 25 of Set 1 | yar-sale
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | nalut
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | muisne
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | cayenne
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | opuwo
# Processing Record 36 of Set 1 | vila franca do campo
# Processing Record 37 of Set 1 | kamenka
# Processing Record 38 of Set 1 | senanga
# Processing Record 39 of Set 1 | san vicente
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | tahoua
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | aksarka
# Processing Record 46 of Set 1 | kez
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | kavieng
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | geraldton
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | shubarshi
# Processing Record 6 of Set 2 | palmer
# Processing Record 7 of Set 2 | san mateo del mar
# Processing Record 8 of Set 2 | primero de marzo
# Processing Record 9 of Set 2 | chlorakas
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | sangar
# Processing Record 12 of Set 2 | mahibadhoo
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | nova olinda do norte
# Processing Record 15 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 2 | mahebourg
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | zhezkazgan
# Processing Record 19 of Set 2 | stony mountain
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | susehri
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 2 | tinqueux
# Processing Record 26 of Set 2 | ngama
# Processing Record 27 of Set 2 | kalevala
# Processing Record 28 of Set 2 | lexington
# Processing Record 29 of Set 2 | langevag
# Processing Record 30 of Set 2 | saint-pierre
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | arman
# Processing Record 34 of Set 2 | vardo
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | mombetsu
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | anzhero-sudzhensk
# Processing Record 40 of Set 2 | kahului
# Processing Record 41 of Set 2 | naze
# Processing Record 42 of Set 2 | aykhal
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | port hawkesbury
# Processing Record 46 of Set 2 | campoverde
# Processing Record 47 of Set 2 | gillette
# Processing Record 48 of Set 2 | kurchum
# Processing Record 49 of Set 2 | canaries
# Processing Record 50 of Set 2 | bilma
# Processing Record 1 of Set 3 | emerald
# Processing Record 2 of Set 3 | half moon bay
# Processing Record 3 of Set 3 | yatou
# Processing Record 4 of Set 3 | pak phanang
# Processing Record 5 of Set 3 | beringovskiy
# Processing Record 6 of Set 3 | intibuca
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | rawson
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | richards bay
# Processing Record 11 of Set 3 | ostrovnoy
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 3 | honiara
# Processing Record 15 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | bongouanou
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | xiamen
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | port-gentil
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | maltahohe
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | fort saint james
# Processing Record 30 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | haines junction
# Processing Record 33 of Set 3 | newnan
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | mabaruma
# Processing Record 36 of Set 3 | dire
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | envira
# Processing Record 40 of Set 3 | los llanos de aridane
# Processing Record 41 of Set 3 | port blair
# Processing Record 42 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 3 | yulara
# Processing Record 44 of Set 3 | margate
# Processing Record 45 of Set 3 | solnechnyy
# Processing Record 46 of Set 3 | christchurch
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 3 | brooks
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | sorland
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | jega
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | ewa beach
# Processing Record 6 of Set 4 | olga
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | matara
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | jabinyanah
# Processing Record 12 of Set 4 | boyolangu
# Processing Record 13 of Set 4 | juneau
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | dukat
# Processing Record 16 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 4 | tarakan
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | broken hill
# Processing Record 20 of Set 4 | cotonou
# Processing Record 21 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 4 | dhidhdhoo
# Processing Record 23 of Set 4 | codrington
# Processing Record 24 of Set 4 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 25 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 4 | bubaque
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | ahipara
# Processing Record 29 of Set 4 | dalnerechensk
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | kapiri mposhi
# Processing Record 32 of Set 4 | constitucion
# Processing Record 33 of Set 4 | nikel
# Processing Record 34 of Set 4 | baykit
# Processing Record 35 of Set 4 | castrovillari
# Processing Record 36 of Set 4 | hualmay
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | qandala
# Processing Record 39 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 4 | bathsheba
# Processing Record 41 of Set 4 | honningsvag
# Processing Record 42 of Set 4 | vanavara
# Processing Record 43 of Set 4 | ballina
# Processing Record 44 of Set 4 | ostersund
# Processing Record 45 of Set 4 | manoharpur
# Processing Record 46 of Set 4 | horizontina
# Processing Record 47 of Set 4 | lac du bonnet
# Processing Record 48 of Set 4 | lokosovo
# Processing Record 49 of Set 4 | padang
# Processing Record 50 of Set 4 | bethel
# Processing Record 1 of Set 5 | sibolga
# Processing Record 2 of Set 5 | ucluelet
# Processing Record 3 of Set 5 | taunggyi
# Processing Record 4 of Set 5 | kansanshi
# Processing Record 5 of Set 5 | gambela
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | marrakesh
# Processing Record 8 of Set 5 | chenghai
# Processing Record 9 of Set 5 | kyaikkami
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | havoysund
# Processing Record 12 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 5 | cockburn town
# Processing Record 14 of Set 5 | mayo
# Processing Record 15 of Set 5 | laguna
# Processing Record 16 of Set 5 | springdale
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | viedma
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | america dourada
# Processing Record 21 of Set 5 | hazorasp
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | chaska
# Processing Record 24 of Set 5 | waverly
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | saravan
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | belyy yar
# Processing Record 29 of Set 5 | saint-francois
# Processing Record 30 of Set 5 | soyo
# Processing Record 31 of Set 5 | alta floresta
# Processing Record 32 of Set 5 | pacific grove
# Processing Record 33 of Set 5 | goderich
# Processing Record 34 of Set 5 | abu dhabi
# Processing Record 35 of Set 5 | sai buri
# Processing Record 36 of Set 5 | carnarvon
# Processing Record 37 of Set 5 | nishihara
# Processing Record 38 of Set 5 | okha
# Processing Record 39 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 5 | praia
# Processing Record 41 of Set 5 | tasiilaq
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | clyde river
# Processing Record 44 of Set 5 | changli
# Processing Record 45 of Set 5 | kerchevskiy
# Processing Record 46 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 5 | petapa
# Processing Record 48 of Set 5 | visnes
# Processing Record 49 of Set 5 | alofi
# Processing Record 50 of Set 5 | ellisras
# Processing Record 1 of Set 6 | muros
# Processing Record 2 of Set 6 | gulmarg
# Processing Record 3 of Set 6 | souillac
# Processing Record 4 of Set 6 | marawi
# Processing Record 5 of Set 6 | samarai
# Processing Record 6 of Set 6 | dieppe
# Processing Record 7 of Set 6 | viransehir
# Processing Record 8 of Set 6 | pareora
# Processing Record 9 of Set 6 | izmalkovo
# Processing Record 10 of Set 6 | corowa
# Processing Record 11 of Set 6 | alekseyevskaya
# Processing Record 12 of Set 6 | buala
# Processing Record 13 of Set 6 | bardiyah
# Processing Record 14 of Set 6 | gat
# Processing Record 15 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 6 | olavarria
# Processing Record 17 of Set 6 | kirakira
# Processing Record 18 of Set 6 | lata
# Processing Record 19 of Set 6 | coquimbo
# Processing Record 20 of Set 6 | celestun
# Processing Record 21 of Set 6 | egvekinot
# Processing Record 22 of Set 6 | oranjemund
# Processing Record 23 of Set 6 | glazov
# Processing Record 24 of Set 6 | koprivnica
# Processing Record 25 of Set 6 | acajutla
# Processing Record 26 of Set 6 | batagay-alyta
# Processing Record 27 of Set 6 | verkhnyaya inta
# Processing Record 28 of Set 6 | san cristobal
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | el bagre
# Processing Record 31 of Set 6 | maniitsoq
# Processing Record 32 of Set 6 | cabildo
# Processing Record 33 of Set 6 | qaqortoq
# Processing Record 34 of Set 6 | sur
# Processing Record 35 of Set 6 | shiraoi
# Processing Record 36 of Set 6 | mukhen
# Processing Record 37 of Set 6 | ciudad bolivar
# Processing Record 38 of Set 6 | eureka
# Processing Record 39 of Set 6 | nouadhibou
# Processing Record 40 of Set 6 | springbok
# Processing Record 41 of Set 6 | kaduna
# Processing Record 42 of Set 6 | marzuq
# Processing Record 43 of Set 6 | guerrero negro
# Processing Record 44 of Set 6 | coolum beach
# Processing Record 45 of Set 6 | xining
# Processing Record 46 of Set 6 | powell river
# Processing Record 47 of Set 6 | konyar
# Processing Record 48 of Set 6 | hirara
# Processing Record 49 of Set 6 | san angelo
# Processing Record 50 of Set 6 | tiksi
# Processing Record 1 of Set 7 | taoudenni
# Processing Record 2 of Set 7 | tilichiki
# Processing Record 3 of Set 7 | fort nelson
# Processing Record 4 of Set 7 | coria
# Processing Record 5 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 7 | nizhniy odes
# Processing Record 7 of Set 7 | vagay
# Processing Record 8 of Set 7 | tura
# Processing Record 9 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 7 | oksfjord
# Processing Record 11 of Set 7 | norman wells
# Processing Record 12 of Set 7 | araouane
# Processing Record 13 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 15 of Set 7 | aripuana
# Processing Record 16 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 7 | westport
# Processing Record 18 of Set 7 | appleton
# Processing Record 19 of Set 7 | teixeira
# Processing Record 20 of Set 7 | huarmey
# Processing Record 21 of Set 7 | broome
# Processing Record 22 of Set 7 | caala
# Processing Record 23 of Set 7 | severo-kurilsk
# Processing Record 24 of Set 7 | melendugno
# Processing Record 25 of Set 7 | oussouye
# Processing Record 26 of Set 7 | xai-xai
# Processing Record 27 of Set 7 | inta
# Processing Record 28 of Set 7 | meilen
# Processing Record 29 of Set 7 | mogadishu
# Processing Record 30 of Set 7 | itaituba
# Processing Record 31 of Set 7 | bang saphan
# Processing Record 32 of Set 7 | port keats
# Processing Record 33 of Set 7 | zouxian
# City not found. Skipping...
# Processing Record 34 of Set 7 | batemans bay
# Processing Record 35 of Set 7 | kokemaki
# Processing Record 36 of Set 7 | tocopilla
# Processing Record 37 of Set 7 | hurricane
# Processing Record 38 of Set 7 | tenkodogo
# Processing Record 39 of Set 7 | kruisfontein
# Processing Record 40 of Set 7 | prince rupert
# Processing Record 41 of Set 7 | nago
# Processing Record 42 of Set 7 | bac lieu
# Processing Record 43 of Set 7 | antofagasta
# Processing Record 44 of Set 7 | harlingen
# Processing Record 45 of Set 7 | coihaique
# Processing Record 46 of Set 7 | atar
# Processing Record 47 of Set 7 | ilulissat
# Processing Record 48 of Set 7 | nioro
# Processing Record 49 of Set 7 | humaita
# Processing Record 50 of Set 7 | copiapo
# Processing Record 1 of Set 8 | horsham
# Processing Record 2 of Set 8 | leningradskiy
# Processing Record 3 of Set 8 | collie
# Processing Record 4 of Set 8 | polunochnoye
# Processing Record 5 of Set 8 | nantucket
# Processing Record 6 of Set 8 | waddan
# Processing Record 7 of Set 8 | saint george
# Processing Record 8 of Set 8 | lavrentiya
# Processing Record 9 of Set 8 | savinka
# Processing Record 10 of Set 8 | fernandina beach
# Processing Record 11 of Set 8 | lasa
# Processing Record 12 of Set 8 | zyryanka
# Processing Record 13 of Set 8 | calama
# Processing Record 14 of Set 8 | gonbad-e qabus
# Processing Record 15 of Set 8 | cordoba
# Processing Record 16 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 8 | great bend
# Processing Record 18 of Set 8 | uyovu
# Processing Record 19 of Set 8 | derzhavinsk
# Processing Record 20 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 8 | axim
# Processing Record 22 of Set 8 | mo i rana
# Processing Record 23 of Set 8 | la ronge
# Processing Record 24 of Set 8 | santa catarina de tepehuanes
# Processing Record 25 of Set 8 | saint-joseph
# Processing Record 26 of Set 8 | mount isa
# Processing Record 27 of Set 8 | ugoofaaru
# Processing Record 28 of Set 8 | sinnamary
# Processing Record 29 of Set 8 | karasjok
# Processing Record 30 of Set 8 | martinez
# Processing Record 31 of Set 8 | tsiroanomandidy
# Processing Record 32 of Set 8 | san policarpo
# Processing Record 33 of Set 8 | tautira
# Processing Record 34 of Set 8 | mao
# Processing Record 35 of Set 8 | olafsvik
# Processing Record 36 of Set 8 | salalah
# Processing Record 37 of Set 8 | santona
# Processing Record 38 of Set 8 | bengkulu
# Processing Record 39 of Set 8 | cabo san lucas
# Processing Record 40 of Set 8 | san andres
# Processing Record 41 of Set 8 | sept-iles
# Processing Record 42 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 8 | iwanai
# Processing Record 44 of Set 8 | najran
# Processing Record 45 of Set 8 | teisani
# Processing Record 46 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 8 | urumqi
# Processing Record 49 of Set 8 | hatta
# Processing Record 50 of Set 8 | biak
# Processing Record 1 of Set 9 | pisco
# Processing Record 2 of Set 9 | xiongzhou
# Processing Record 3 of Set 9 | vrede
# Processing Record 4 of Set 9 | bagaciu
# Processing Record 5 of Set 9 | lubango
# Processing Record 6 of Set 9 | chute-aux-outardes
# Processing Record 7 of Set 9 | anadyr
# Processing Record 8 of Set 9 | muhammadabad
# Processing Record 9 of Set 9 | puerto escondido
# Processing Record 10 of Set 9 | san luis
# Processing Record 11 of Set 9 | omboue
# Processing Record 12 of Set 9 | dinhata
# Processing Record 13 of Set 9 | zhigansk
# Processing Record 14 of Set 9 | paso de los toros
# Processing Record 15 of Set 9 | altay
# Processing Record 16 of Set 9 | hobyo
# Processing Record 17 of Set 9 | arlit
# Processing Record 18 of Set 9 | quatre cocos
# Processing Record 19 of Set 9 | galveston
# Processing Record 20 of Set 9 | mhlambanyatsi
# Processing Record 21 of Set 9 | san matias
# Processing Record 22 of Set 9 | leh
# Processing Record 23 of Set 9 | hoa binh
# Processing Record 24 of Set 9 | ust-kuyga
# Processing Record 25 of Set 9 | skovorodino
# Processing Record 26 of Set 9 | manggar
# Processing Record 27 of Set 9 | itarema
# Processing Record 28 of Set 9 | jalu
# Processing Record 29 of Set 9 | sciacca
# Processing Record 30 of Set 9 | buochs
# Processing Record 31 of Set 9 | port moresby
# Processing Record 32 of Set 9 | narsaq
# Processing Record 33 of Set 9 | south lake tahoe
# Processing Record 34 of Set 9 | tiarei
# Processing Record 35 of Set 9 | navirai
# Processing Record 36 of Set 9 | bertoua
# Processing Record 37 of Set 9 | cochrane
# Processing Record 38 of Set 9 | albanel
# Processing Record 39 of Set 9 | ceres
# Processing Record 40 of Set 9 | tournai
# Processing Record 41 of Set 9 | asosa
# Processing Record 42 of Set 9 | tenenkou
# Processing Record 43 of Set 9 | mecca
# Processing Record 44 of Set 9 | sisimiut
# Processing Record 45 of Set 9 | chandur bazar
# Processing Record 46 of Set 9 | tual
# Processing Record 47 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 9 | vestmanna
# Processing Record 49 of Set 9 | puerto princesa
# Processing Record 50 of Set 9 | komsomolskiy
# Processing Record 1 of Set 10 | malanje
# Processing Record 2 of Set 10 | wattegama
# Processing Record 3 of Set 10 | lady lake
# Processing Record 4 of Set 10 | puerto madryn
# Processing Record 5 of Set 10 | toamasina
# Processing Record 6 of Set 10 | porto santo
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | xam nua
# Processing Record 9 of Set 10 | husavik
# Processing Record 10 of Set 10 | pudozh
# Processing Record 11 of Set 10 | villa rica
# Processing Record 12 of Set 10 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 13 of Set 10 | port macquarie
# Processing Record 14 of Set 10 | salamanca
# Processing Record 15 of Set 10 | iquique
# Processing Record 16 of Set 10 | caravelas
# Processing Record 17 of Set 10 | ornskoldsvik
# Processing Record 18 of Set 10 | port hedland
# Processing Record 19 of Set 10 | tamandare
# Processing Record 20 of Set 10 | czluchow
# Processing Record 21 of Set 10 | toyooka
# Processing Record 22 of Set 10 | general roca
# Processing Record 23 of Set 10 | seymchan
# Processing Record 24 of Set 10 | lompoc
# Processing Record 25 of Set 10 | teya
# Processing Record 26 of Set 10 | maki
# Processing Record 27 of Set 10 | asfi
# Processing Record 28 of Set 10 | halifax
# Processing Record 29 of Set 10 | mahanoro
# Processing Record 30 of Set 10 | mitsamiouli
# Processing Record 31 of Set 10 | mbeya
# Processing Record 32 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 33 of Set 10 | alyangula
# Processing Record 34 of Set 10 | gaoua
# Processing Record 35 of Set 10 | aklavik
# Processing Record 36 of Set 10 | port hardy
# Processing Record 37 of Set 10 | amazar
# Processing Record 38 of Set 10 | north bend
# Processing Record 39 of Set 10 | alexandria
# Processing Record 40 of Set 10 | whitecourt
# Processing Record 41 of Set 10 | tshikapa
# Processing Record 42 of Set 10 | moroni
# Processing Record 43 of Set 10 | sann
# Processing Record 44 of Set 10 | whakatane
# Processing Record 45 of Set 10 | gannan
# Processing Record 46 of Set 10 | ossora
# Processing Record 47 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 10 | sola
# Processing Record 49 of Set 10 | boulder
# Processing Record 50 of Set 10 | miri
# Processing Record 1 of Set 11 | mori
# Processing Record 2 of Set 11 | takoradi
# Processing Record 3 of Set 11 | atbasar
# Processing Record 4 of Set 11 | port-cartier
# Processing Record 5 of Set 11 | gamba
# Processing Record 6 of Set 11 | lircay
# Processing Record 7 of Set 11 | martapura
# Processing Record 8 of Set 11 | dunedin
# Processing Record 9 of Set 11 | lagoa
# Processing Record 10 of Set 11 | muravlenko
# Processing Record 11 of Set 11 | esperance
# Processing Record 12 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 11 | the valley
# Processing Record 14 of Set 11 | rocha
# Processing Record 15 of Set 11 | timra
# Processing Record 16 of Set 11 | eskisehir
# Processing Record 17 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 11 | west bay
# Processing Record 19 of Set 11 | okhotsk
# Processing Record 20 of Set 11 | valparaiso
# Processing Record 21 of Set 11 | rezh
# Processing Record 22 of Set 11 | ust-kulom
# Processing Record 23 of Set 11 | esfarayen
# Processing Record 24 of Set 11 | buenaventura
# Processing Record 25 of Set 11 | touros
# Processing Record 26 of Set 11 | lebanon
# Processing Record 27 of Set 11 | jiazi
# Processing Record 28 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 11 | praia da vitoria
# Processing Record 30 of Set 11 | yamada
# Processing Record 31 of Set 11 | grand gaube
# Processing Record 32 of Set 11 | farsund
# Processing Record 33 of Set 11 | faya
# Processing Record 34 of Set 11 | acarau
# Processing Record 35 of Set 11 | opole lubelskie
# Processing Record 36 of Set 11 | excelsior springs
# Processing Record 37 of Set 11 | eyl
# Processing Record 38 of Set 11 | holly springs
# Processing Record 39 of Set 11 | isangel
# Processing Record 40 of Set 11 | manchester
# Processing Record 41 of Set 11 | adrar
# Processing Record 42 of Set 11 | cherskiy
# Processing Record 43 of Set 11 | dwarka
# Processing Record 44 of Set 11 | brigantine
# Processing Record 45 of Set 11 | poya
# Processing Record 46 of Set 11 | maridi
# Processing Record 47 of Set 11 | mezhdurechensk
# Processing Record 48 of Set 11 | kaka
# Processing Record 49 of Set 11 | tacna
# Processing Record 50 of Set 11 | hutchinson
# Processing Record 1 of Set 12 | asau
# Processing Record 2 of Set 12 | marystown
# Processing Record 3 of Set 12 | onokhoy
# Processing Record 4 of Set 12 | conceicao das alagoas
# Processing Record 5 of Set 12 | san rafael del sur
# Processing Record 6 of Set 12 | zabolotovka
# Processing Record 7 of Set 12 | portland
# Processing Record 8 of Set 12 | khovu-aksy
# Processing Record 9 of Set 12 | sao joao da barra
# Processing Record 10 of Set 12 | ziarat
# Processing Record 11 of Set 12 | fortuna
# Processing Record 12 of Set 12 | gizo
# Processing Record 13 of Set 12 | tessalit
# Processing Record 14 of Set 12 | biga
# Processing Record 15 of Set 12 | danjiangkou
# Processing Record 16 of Set 12 | aberystwyth
# Processing Record 17 of Set 12 | aguilas
# Processing Record 18 of Set 12 | erenhot
# Processing Record 19 of Set 12 | black river
# Processing Record 20 of Set 12 | saint anthony
# Processing Record 21 of Set 12 | cangucu
# Processing Record 22 of Set 12 | beidao
# Processing Record 23 of Set 12 | grivenskaya
# Processing Record 24 of Set 12 | noumea
# Processing Record 25 of Set 12 | chuy
# Processing Record 26 of Set 12 | waw
# Processing Record 27 of Set 12 | hay river
# Processing Record 28 of Set 12 | chegdomyn
# Processing Record 29 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 12 | sandane
# Processing Record 31 of Set 12 | kangaba
# Processing Record 32 of Set 12 | hare bay
# Processing Record 33 of Set 12 | kautokeino
# Processing Record 34 of Set 12 | saint-augustin
# Processing Record 35 of Set 12 | harbour breton
# Processing Record 36 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 12 | santa cruz
# Processing Record 38 of Set 12 | pavda
# City not found. Skipping...
# Processing Record 39 of Set 12 | shimoda
# Processing Record 40 of Set 12 | seoul
# Processing Record 41 of Set 12 | mackay
# Processing Record 42 of Set 12 | machachi
# Processing Record 43 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 44 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 12 | san gabriel casa blanca
# Processing Record 46 of Set 12 | cabedelo
# Processing Record 47 of Set 12 | mizan teferi
# Processing Record 48 of Set 12 | masyaf
# Processing Record 49 of Set 12 | santa maria
# Processing Record 50 of Set 12 | keetmanshoop
# Processing Record 1 of Set 13 | batsfjord
# Processing Record 2 of Set 13 | alice springs
# Processing Record 3 of Set 13 | bukama
# Processing Record 4 of Set 13 | cap malheureux
# Processing Record 5 of Set 13 | inverell
# Processing Record 6 of Set 13 | ranong
# Processing Record 7 of Set 13 | kargil
# Processing Record 8 of Set 13 | rio abajo
# Processing Record 9 of Set 13 | pouebo
# Processing Record 10 of Set 13 | san lawrenz
# Processing Record 11 of Set 13 | poum
# Processing Record 12 of Set 13 | nelson bay
# Processing Record 13 of Set 13 | havelock
# Processing Record 14 of Set 13 | carupano
# Processing Record 15 of Set 13 | mehamn
# Processing Record 16 of Set 13 | sao filipe
# Processing Record 17 of Set 13 | homer
# Processing Record 18 of Set 13 | thohoyandou
# Processing Record 19 of Set 13 | rio branco
# Processing Record 20 of Set 13 | zyryanovsk
# Processing Record 21 of Set 13 | acapulco
# Processing Record 22 of Set 13 | nizhnekamsk
# Processing Record 23 of Set 13 | amparafaravola
# Processing Record 24 of Set 13 | ketchikan
# Processing Record 25 of Set 13 | poindimie
# Processing Record 26 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 27 of Set 13 | saint-louis
# Processing Record 28 of Set 13 | bandarbeyla
# Processing Record 29 of Set 13 | vanimo
# Processing Record 30 of Set 13 | long beach
# Processing Record 31 of Set 13 | kushiro
# Processing Record 32 of Set 13 | makhinjauri
# Processing Record 33 of Set 13 | menongue
# Processing Record 34 of Set 13 | ukiah
# Processing Record 35 of Set 13 | tchollire
# Processing Record 36 of Set 13 | vila
# Processing Record 37 of Set 13 | bronnoysund
# Processing Record 38 of Set 13 | miraflores
# Processing Record 39 of Set 13 | winnemucca
# Processing Record 40 of Set 13 | necochea
# Processing Record 41 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 13 | mareeba
# Processing Record 43 of Set 13 | boa vista
# Processing Record 44 of Set 13 | mulanje
# Processing Record 45 of Set 13 | bilibino
# Processing Record 46 of Set 13 | vestmannaeyjar
# Processing Record 47 of Set 13 | flinders
# Processing Record 48 of Set 13 | anahuac
# Processing Record 49 of Set 13 | lapi
# Processing Record 50 of Set 13 | totness
# Processing Record 1 of Set 14 | wanning
# Processing Record 2 of Set 14 | merritt island
# Processing Record 3 of Set 14 | kenai
# Processing Record 4 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 14 | migori
# Processing Record 7 of Set 14 | roebourne
# Processing Record 8 of Set 14 | uvinza
# Processing Record 9 of Set 14 | bundaberg
# Processing Record 10 of Set 14 | srivardhan
# Processing Record 11 of Set 14 | promissao
# Processing Record 12 of Set 14 | ibra
# Processing Record 13 of Set 14 | malabo
# Processing Record 14 of Set 14 | ranghulu
# Processing Record 15 of Set 14 | chukhloma
# Processing Record 16 of Set 14 | leshukonskoye
# Processing Record 17 of Set 14 | korla
# Processing Record 18 of Set 14 | heihe
# Processing Record 19 of Set 14 | south shields
# Processing Record 20 of Set 14 | farmington
# Processing Record 21 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 14 | samarkand
# Processing Record 23 of Set 14 | general pico
# Processing Record 24 of Set 14 | innisfail
# Processing Record 25 of Set 14 | nkan
# Processing Record 26 of Set 14 | marsa matruh
# Processing Record 27 of Set 14 | along
# Processing Record 28 of Set 14 | chapais
# Processing Record 29 of Set 14 | scicli
# Processing Record 30 of Set 14 | kysyl-syr
# Processing Record 31 of Set 14 | bud
# Processing Record 32 of Set 14 | armizonskoye
# Processing Record 33 of Set 14 | chubbuck
# Processing Record 34 of Set 14 | we
# City not found. Skipping...
# Processing Record 35 of Set 14 | algiers
# Processing Record 36 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 37 of Set 14 | mackenzie
# Processing Record 38 of Set 14 | neryungri
# Processing Record 39 of Set 14 | san carlos de bariloche
# Processing Record 40 of Set 14 | kiama
# Processing Record 41 of Set 14 | kumphawapi
# Processing Record 42 of Set 14 | tukrah
# Processing Record 43 of Set 14 | alekseyevsk
# Processing Record 44 of Set 14 | bykovo
# Processing Record 45 of Set 14 | hambantota
# Processing Record 46 of Set 14 | kyra
# Processing Record 47 of Set 14 | warrington
# Processing Record 48 of Set 14 | chalus
# Processing Record 49 of Set 14 | vao
# Processing Record 50 of Set 14 | benghazi
# Processing Record 1 of Set 15 | havre-saint-pierre
# Processing Record 2 of Set 15 | paralimni
# Processing Record 3 of Set 15 | sangmelima
# Processing Record 4 of Set 15 | lamu
# Processing Record 5 of Set 15 | correntina
# Processing Record 6 of Set 15 | channahon
# Processing Record 7 of Set 15 | ocampo
# Processing Record 8 of Set 15 | aasiaat
# Processing Record 9 of Set 15 | aras
# Processing Record 10 of Set 15 | nicoya
# Processing Record 11 of Set 15 | colwyn bay
# Processing Record 12 of Set 15 | corpus christi
# Processing Record 13 of Set 15 | eresos
# Processing Record 14 of Set 15 | kerema
# Processing Record 15 of Set 15 | katsuura
# Processing Record 16 of Set 15 | tubuala
# Processing Record 17 of Set 15 | riyadh
# Processing Record 18 of Set 15 | el alto
# Processing Record 19 of Set 15 | mineros
# Processing Record 20 of Set 15 | san ramon
# Processing Record 21 of Set 15 | sechura
# Processing Record 22 of Set 15 | dibulla
# Processing Record 23 of Set 15 | valleyview
# Processing Record 24 of Set 15 | okahandja
# Processing Record 25 of Set 15 | pimenta bueno
# Processing Record 26 of Set 15 | dhanbad
# Processing Record 27 of Set 15 | sistranda
# Processing Record 28 of Set 15 | natal
# Processing Record 29 of Set 15 | tsogni
# Processing Record 30 of Set 15 | aquiraz
# Processing Record 31 of Set 15 | manutuke
# Processing Record 32 of Set 15 | laibin
# Processing Record 33 of Set 15 | kasongo-lunda
# Processing Record 34 of Set 15 | moa
# Processing Record 35 of Set 15 | port lincoln
# Processing Record 36 of Set 15 | talcahuano
# Processing Record 37 of Set 15 | sabla
# Processing Record 38 of Set 15 | pasni
# Processing Record 39 of Set 15 | pangnirtung
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Grindavik  63.8424  -22.4338     52.27        87         100
# 1  Punta Arenas -53.1500  -70.9167     39.31        81           0
# 2     Kavaratti  10.5669   72.6420     80.58        82         100
# 3         Bowen -20.0167  148.2333     66.70        70           0
# 4        Maceio  -9.6658  -35.7353     75.85        78           1
# 5          Hami  42.8000   93.4500     80.35        29          96
# 6    Bredasdorp -34.5322   20.0403     53.89        86         100
# 7     Cape Town -33.9258   18.4232     55.90        81           8
# 8   Abong Mbang   3.9833   13.1833     66.72        96         100
# 9   Kangaatsiaq  68.3065  -53.4641     43.77        82          95
#
#    Wind Speed Current Description Country                 Date
# 0        4.61     overcast clouds      IS  2022-07-19 00:14:20
# 1       26.46          light rain      CL  2022-07-19 00:14:21
# 2       22.24     overcast clouds      IN  2022-07-19 00:13:06
# 3        9.51           clear sky      AU  2022-07-19 00:14:21
# 4       13.94           clear sky      BR  2022-07-19 00:14:21
# 5        3.13     overcast clouds      CN  2022-07-19 00:14:22
# 6        1.92     overcast clouds      ZA  2022-07-19 00:14:22
# 7        7.00           clear sky      ZA  2022-07-19 00:13:11
# 8        3.06     overcast clouds      CM  2022-07-19 00:14:22
# 9        3.94     overcast clouds      GL  2022-07-19 00:14:23

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Grindavik      IS  63.8424  -22.4338     52.27        87         100
# 1  Punta Arenas      CL -53.1500  -70.9167     39.31        81           0
# 2     Kavaratti      IN  10.5669   72.6420     80.58        82         100
# 3         Bowen      AU -20.0167  148.2333     66.70        70           0
# 4        Maceio      BR  -9.6658  -35.7353     75.85        78           1
# 5          Hami      CN  42.8000   93.4500     80.35        29          96
# 6    Bredasdorp      ZA -34.5322   20.0403     53.89        86         100
# 7     Cape Town      ZA -33.9258   18.4232     55.90        81           8
# 8   Abong Mbang      CM   3.9833   13.1833     66.72        96         100
# 9   Kangaatsiaq      GL  68.3065  -53.4641     43.77        82          95
#
#    Wind Speed Current Description
# 0        4.61     overcast clouds
# 1       26.46          light rain
# 2       22.24     overcast clouds
# 3        9.51           clear sky
# 4       13.94           clear sky
# 5        3.13     overcast clouds
# 6        1.92     overcast clouds
# 7        7.00           clear sky
# 8        3.06     overcast clouds
# 9        3.94     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
